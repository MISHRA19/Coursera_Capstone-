# %% [markdown]
# # Toronto Health Seminar - Searching Venues of interest for Delegates and Families

# %% [markdown]
# ## Introduction

# %% [markdown]
# Toronto has been hosting its famous health congregation Seminar since 2010. Its the time of the year when health professionals converge in hordes to participate, learn and share the latest technologies and breakthroughs in their field.
# It’s a Five-day event and the professionals are also accompanied by their families.
# This year is no exception. However, with the COVID-19 threat the seminar has been postponed to August, considering that the threat is reduced by that time.
# Lights and Action the event management company entrusted with the logistics of this event has employed me to provide them with data points and map that would assist them in arriving at probable logistics with regards to:
# 1. Hotels as Accommodation
# 2. Shopping malls and Event places
# 3. Parks,Restaurant,Cafetaria for family recreation
#
# This Project Therefore would have the objective of looking at such data points,clean them,merge them into probable sets and visualize the same with maps.

# %% [markdown]
# ## Lights Camera Code - But First lets import Libraries

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0     conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Mapping out Credentials in Foursquare API

# %%
ClIENT_ID = 'NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN' # your Foursquare ID
ClIENT_SECRET = 'G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN
# Foursquare_Secret:G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU

# %% [markdown]
# ## City Definition and Latitude and Longitude retrieval

# %%
# define the city and get its latitude & longitude 
city = 'Toronto'
geolocator = Nominatim(user_agent="My-aaplication")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print("Geographical Cordinates of the City of {} is {},{}".format(city,latitude, longitude))
# Out:
# Geographical Cordinates of the City of Toronto is 43.653963,-79.387207

# %% [markdown]
# ## Accomodation/Hotel Search

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN&client_secret=G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU&ll=43.653963,-79.387207&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
# 3  5545d07e498e2facac03f666  123 Queen Street West          CA       Toronto
# 4  4f53fb2ee4b036244bea152f                    NaN          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                432
# 1           Canada  Queen & St. Patrick                400
# 2           Canada      at somewhere St                500
# 3           Canada        at Bay Street                376
# 4           Canada                  NaN                129
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Test Drive (at somewhere St), Toronto ON ...
# 3  [123 Queen Street West (at Bay Street), Toront...
# 4                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...     43.650594
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
# 3  [{'label': 'display', 'lat': 43.65119976208405...     43.651200
# 4  [{'label': 'display', 'lat': 43.654947, 'lng':...     43.654947
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384530                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.387894                   NaN             M2M 2M2             ON
# 3    -79.384520    Financial District                 NaN             ON
# 4    -79.386359                   NaN                 NaN             ON
#
#                                              name    referralId venuePage.id
# 0                   Sheraton Centre Toronto Hotel  v-1584472035          NaN
# 1                  The Rex Hotel Jazz & Blues Bar  v-1584472035     62225795
# 2                                  VFM Test Hotel  v-1584472035          NaN
# 3  Sheraton Centre Toronto Hotel - Grand Ballroom  v-1584472035          NaN
# 4                                 Stathcona Hotel  v-1584472035          NaN

# %% [markdown]
# ## Cleaning the data frame
# #### Trivia - Cleaning consumes 80% of a Data Scientists Workload

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2                                  VFM Test Hotel      Hotel
# 3  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
# 4                                 Stathcona Hotel      Hotel
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       432
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
# 3  123 Queen Street West  CA  Toronto  Canada        at Bay Street       376
# 4                    NaN  CA  Toronto  Canada                  NaN       129
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [123 Test Drive (at somewhere St), Toronto ON ...
# 3  [123 Queen Street West (at Bay Street), Toront...
# 4                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...  43.650594 -79.384530
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
# 3  [{'label': 'display', 'lat': 43.65119976208405...  43.651200 -79.384520
# 4  [{'label': 'display', 'lat': 43.654947, 'lng':...  43.654947 -79.386359
#
#          neighborhood postalCode state                        id
# 0                 NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1                 NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2                 NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90
# 3  Financial District        NaN    ON  5545d07e498e2facac03f666
# 4                 NaN        NaN    ON  4f53fb2ee4b036244bea152f

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                                   VFM Test Hotel                   Hotel
# 3   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 4                                  Stathcona Hotel                   Hotel
# 5                Sheraton Centre Hotel Club Lounge                  Lounge
# 6                                        650 Hotel                   Hotel
# 7                                Be SixFifty Hotel                   Hotel
# 8                             DoubleTree by Hilton                   Hotel
# 9                               Shangri-La Toronto                   Hotel
# 10                                          Hilton                   Hotel
# 11    Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                           89 Chestnut Residence  College Residence Hall
# 13                   Op mijn hotelkamer In Toronto                   Hotel
# 14          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 15                                  Fitness Centre                     Gym
# 16                                  Fitness Centre                     Gym
# 17                                            Pool                    Pool
# 18                                   Kumar For Men             Men's Store
# 19                                  Grand Ballroom             Event Space
# 20                                   Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 3   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 4                     NaN  43.654947 -79.386359        NaN       ON
# 5                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 6          650 Bay Street  43.657046 -79.384411        NaN       ON
# 7          650 Bay Street  43.657120 -79.384560        NaN       ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 12        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 13                    NaN  43.654235 -79.386208        NaN       ON
# 14    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 15        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 17       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 18        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON
# 20        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2                                 VFM Test Hotel                   Hotel
# 8                           DoubleTree by Hilton                   Hotel
# 9                             Shangri-La Toronto                   Hotel
# 10                                        Hilton                   Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 12                         89 Chestnut Residence  College Residence Hall
# 14        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 15                                Fitness Centre                     Gym
# 16                                Fitness Centre                     Gym
# 18                                 Kumar For Men             Men's Store
# 19                                Grand Ballroom             Event Space
# 20                                 Bistro on Two          Breakfast Spot
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 12        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 14    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 15        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 18        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 20        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                                 VFM Test Hotel        Hotel
# 8                           DoubleTree by Hilton        Hotel
# 9                             Shangri-La Toronto        Hotel
# 10                                        Hilton        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 19                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2                                 VFM Test Hotel        Hotel
# 8                           DoubleTree by Hilton        Hotel
# 9                             Shangri-La Toronto        Hotel
# 10                                        Hilton        Hotel
# 11  Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 19                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 8     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 9     188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 10      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 11         525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 19        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 19                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 19  43.651217 -79.383771    M5H 2M9    ON

# %% [markdown]
# ## Time for Fresh air and family time - Parks Please

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN&client_secret=G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU&ll=43.653963,-79.387207&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id          location.address location.cc  \
# 0  4b170e47f964a5208cc123e3        691 University Ave          CA
# 1  4b54deadf964a520a3d027e3                       NaN          CA
# 2  4b9d206bf964a520e69136e3           University Ave.          CA
# 3  4bb79860cf2fc9b616779e02    35 Wellington St. East          CA
# 4  4bfc5019da7120a132df49fd  450 Adelaide Street West          CA
#
#   location.city location.country      location.crossStreet  location.distance  \
# 0       Toronto           Canada             at College St                716
# 1       Toronto           Canada                       NaN                423
# 2       Toronto           Canada         at Wellesley Ave.               1181
# 3       Toronto           Canada                       NaN               1171
# 4       Toronto           Canada  Brant St & Adelaide St W               1183
#
#                            location.formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [University Ave. (at Wellesley Ave.), Toronto ...
# 3       [35 Wellington St. East, Toronto ON, Canada]
# 4  [450 Adelaide Street West (Brant St & Adelaide...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 1  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 2  [{'label': 'display', 'lat': 43.66394609897775...     43.663946
# 3  [{'label': 'display', 'lat': 43.64804835388851...     43.648048
# 4  [{'label': 'display', 'lat': 43.64738759338116...     43.647388
#
#    location.lng location.postalCode location.state  \
# 0    -79.390272             M5G 2P1             ON
# 1    -79.392053                 NaN             ON
# 2    -79.392180             M5R 2E8             ON
# 3    -79.375172                 NaN             ON
# 4    -79.398752                 NaN             ON
#
#                                 name    referralId venuePage.id
# 0        Queen's Park Subway Station  v-1584472035          NaN
# 1                        Grange Park  v-1584472035          NaN
# 2                       Queen's Park  v-1584472035          NaN
# 3                        Berczy Park  v-1584472035          NaN
# 4  St. Andrews Playground / Dog Park  v-1584472035          NaN

# %% [markdown]
# ## Sweeping down the Park Data

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                 name     categories                   address  \
# 0        Queen's Park Subway Station  Metro Station        691 University Ave
# 1                        Grange Park           Park                       NaN
# 2                       Queen's Park           Park           University Ave.
# 3                        Berczy Park           Park    35 Wellington St. East
# 4  St. Andrews Playground / Dog Park           Park  450 Adelaide Street West
#
#    cc     city country               crossStreet  distance  \
# 0  CA  Toronto  Canada             at College St       716
# 1  CA  Toronto  Canada                       NaN       423
# 2  CA  Toronto  Canada         at Wellesley Ave.      1181
# 3  CA  Toronto  Canada                       NaN      1171
# 4  CA  Toronto  Canada  Brant St & Adelaide St W      1183
#
#                                     formattedAddress  \
# 0  [691 University Ave (at College St), Toronto O...
# 1  [btwn College, University, Queen & Spadina, To...
# 2  [University Ave. (at Wellesley Ave.), Toronto ...
# 3       [35 Wellington St. East, Toronto ON, Canada]
# 4  [450 Adelaide Street West (Brant St & Adelaide...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 1  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 2  [{'label': 'display', 'lat': 43.66394609897775...  43.663946 -79.392180
# 3  [{'label': 'display', 'lat': 43.64804835388851...  43.648048 -79.375172
# 4  [{'label': 'display', 'lat': 43.64738759338116...  43.647388 -79.398752
#
#   postalCode state                        id
# 0    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 1        NaN    ON  4b54deadf964a520a3d027e3
# 2    M5R 2E8    ON  4b9d206bf964a520e69136e3
# 3        NaN    ON  4bb79860cf2fc9b616779e02
# 4        NaN    ON  4bfc5019da7120a132df49fd

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                   name  \
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2                         Queen's Park
# 3                          Berczy Park
# 4    St. Andrews Playground / Dog Park
# 5     Residences at College Park North
# 6                        One Park Lane
# 7        Crunch Fitness - College Park
# 8   TTC Streetcar #403 - Victoria park
# 9                 Clarence Square Park
# 10                Bellevue Square Park
# 11              Physiomed College Park
# 12    Toothworks - College Park Dental
# 13                 RBC WaterPark Place
# 14                        College Park
# 15                  Canoe Landing Park
# 16             St Lawrence on the Park
# 17              Trinity Bellwoods Park
# 18                            HTO Park
# 19           Village of Yorkville Park
# 20                         Regent Park
# 21                 Riverdale Park West
# 22                   Barbara Hall Park
# 23        Regent Park Community Centre
# 24                           High Park
# 25             Cawthra Square Dog Park
# 26              Parliament Square Park
# 27             Moss Park Tennis Courts
# 28                        Stanley Park
# 29                 Riverdale Park East
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park               University Ave.
# 3                                       Park        35 Wellington St. East
# 4                                       Park      450 Adelaide Street West
# 5   Residential Building (Apartment / Condo)                   763 Bay St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                       Gym / Fitness Center              382 Yonge Street
# 8                         Light Rail Station                           NaN
# 9                                       Park                   Spadina Ave
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 11                            Medical Center                  382 Yonge St
# 12                          Dentist's Office        444 Yonge St, Unit M16
# 13                                    Office                88 Queens Quay
# 14                             Shopping Mall                  444 Yonge St
# 15                                      Park             50 Fort York Blvd
# 16                                  Building               65 Scadding Ave
# 17                                      Park            1053 Dundas St. W.
# 18                                      Park                  Queen's Quay
# 19                                      Park            115 Cumberland St.
# 20                              Neighborhood                           NaN
# 21                                      Park               500 Gerrard St.
# 22                                      Park                 519 Church St
# 23                          Community Center               465 Dundas St E
# 24                                      Park              1873 Bloor St. W
# 25                                   Dog Run                519 Church St.
# 26                                      Park          44 Parliament Street
# 27                              Tennis Court                     Moss Park
# 28                                      Park              King Street West
# 29                                      Park             550 Broadview Ave
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 3   43.648048 -79.375172        NaN    ON
# 4   43.647388 -79.398752        NaN    ON
# 5   43.659822 -79.385159    M5G 2R3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.659263 -79.382632    M5G 1S8    ON
# 8   43.650735 -79.386921        NaN    ON
# 9   43.644222 -79.394230        NaN    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 11  43.659240 -79.382860    M5B 1S8    ON
# 12  43.660009 -79.383905        NaN    ON
# 13  43.641075 -79.379154        NaN    ON
# 14  43.661237 -79.383603    M5B 2H4    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 16  43.648963 -79.364868        NaN    ON
# 17  43.647072 -79.413756    M5H 2N2    ON
# 18  43.637949 -79.387820        NaN    ON
# 19  43.670186 -79.391180        NaN    ON
# 20  43.660009 -79.364191        NaN    ON
# 21  43.666048 -79.360941    M5A 2H3    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.659512 -79.363048    M5A 2B2    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 25  43.666583 -79.380040        NaN    ON
# 26  43.650264 -79.362195        NaN    ON
# 27  43.655337 -79.371923        NaN    ON
# 28  43.642395 -79.409330        NaN    ON
# 29  43.669951 -79.355493    M4K 2P1    ON

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 2                       Queen's Park
# 5   Residences at College Park North
# 6                      One Park Lane
# 7      Crunch Fitness - College Park
# 10              Bellevue Square Park
# 11            Physiomed College Park
# 14                      College Park
# 15                Canoe Landing Park
# 17            Trinity Bellwoods Park
# 21               Riverdale Park West
# 22                 Barbara Hall Park
# 23      Regent Park Community Centre
# 24                         High Park
# 29               Riverdale Park East
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                                       Park               University Ave.
# 5   Residential Building (Apartment / Condo)                   763 Bay St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                       Gym / Fitness Center              382 Yonge Street
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 11                            Medical Center                  382 Yonge St
# 14                             Shopping Mall                  444 Yonge St
# 15                                      Park             50 Fort York Blvd
# 17                                      Park            1053 Dundas St. W.
# 21                                      Park               500 Gerrard St.
# 22                                      Park                 519 Church St
# 23                          Community Center               465 Dundas St E
# 24                                      Park              1873 Bloor St. W
# 29                                      Park             550 Broadview Ave
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 5   43.659822 -79.385159    M5G 2R3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.659263 -79.382632    M5G 1S8    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 11  43.659240 -79.382860    M5B 1S8    ON
# 14  43.661237 -79.383603    M5B 2H4    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 17  43.647072 -79.413756    M5H 2N2    ON
# 21  43.666048 -79.360941    M5A 2H3    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.659512 -79.363048    M5A 2B2    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 29  43.669951 -79.355493    M4K 2P1    ON

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2             Queen's Park       Park               University Ave.
# 10    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 15      Canoe Landing Park       Park             50 Fort York Blvd
# 17  Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 21     Riverdale Park West       Park               500 Gerrard St.
# 22       Barbara Hall Park       Park                 519 Church St
# 24               High Park       Park              1873 Bloor St. W
# 29     Riverdale Park East       Park             550 Broadview Ave
#
#           lat        lng postalCode state
# 2   43.663946 -79.392180    M5R 2E8    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 17  43.647072 -79.413756    M5H 2N2    ON
# 21  43.666048 -79.360941    M5A 2H3    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 24  43.646479 -79.463425    M6R 2Z3    ON
# 29  43.669951 -79.355493    M4K 2P1    ON

# %% [markdown]
# ## Need for FOOD - Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN&client_secret=G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU&ll=43.653963,-79.387207&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2  [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
# 3  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
# 4  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4b223f5af964a520ba4424e3       225 Front St W          CA       Toronto
# 2  4ad4c05cf964a520dff520e3       301 Front St W          CA       Toronto
# 3  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
# 4  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
#
#   location.country                location.crossStreet  location.distance  \
# 0           Canada                                 NaN                145
# 1           Canada  in InterContinental Toronto Centre               1039
# 2           Canada                     301 Front St. W               1271
# 3           Canada                      at Willison Sq                892
# 4           Canada                       at D'Arcy St.                922
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [225 Front St W (in InterContinental Toronto C...
# 2  [301 Front St W (301 Front St. W), Toronto ON ...
# 3  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 4  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 2  [{'label': 'display', 'lat': 43.64253731714456...     43.642537
# 3  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
# 4  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.385931                     NaN             M5G 1R3             ON
# 1    -79.385113  Entertainment District             M5V 2X3             ON
# 2    -79.387042                     NaN             M5V 2T6             ON
# 3    -79.398039                     NaN             M5T 2E4             ON
# 4    -79.398650       Kensington Market             M5T 2E9             ON
#
#                               name    referralId venuePage.id
# 0  Hemispheres Restaurant & Bistro  v-1584472036          NaN
# 1           Azure Restaurant & Bar  v-1584472036    136175835
# 2                   360 Restaurant  v-1584472036          NaN
# 3   Goldstone Noodle Restaurant 金石  v-1584472036          NaN
# 4           Rol San Restaurant 龍笙棧  v-1584472036          NaN

# %% [markdown]
# ## Restaurant Cleanup

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 1           Azure Restaurant & Bar           Restaurant       225 Front St W
# 2                   360 Restaurant             Wine Bar       301 Front St W
# 3   Goldstone Noodle Restaurant 金石         Noodle House      266 Spadina Ave
# 4           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
#
#    cc     city country                         crossStreet  distance  \
# 0  CA  Toronto  Canada                                 NaN       145
# 1  CA  Toronto  Canada  in InterContinental Toronto Centre      1039
# 2  CA  Toronto  Canada                     301 Front St. W      1271
# 3  CA  Toronto  Canada                      at Willison Sq       892
# 4  CA  Toronto  Canada                       at D'Arcy St.       922
#
#                                     formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  [225 Front St W (in InterContinental Toronto C...
# 2  [301 Front St W (301 Front St. W), Toronto ON ...
# 3  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 4  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
# 2  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
# 3  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
# 4  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3
# 2                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 3                     NaN    M5T 2E4    ON  4b266f05f964a520657b24e3
# 4       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                  Hemispheres Restaurant & Bistro      American Restaurant
# 1                           Azure Restaurant & Bar               Restaurant
# 2                                   360 Restaurant                 Wine Bar
# 3                   Goldstone Noodle Restaurant 金石             Noodle House
# 4                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 5                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 6                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 7               North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 8                     Aroma Fine Indian Restaurant        Indian Restaurant
# 9               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 10                           Victoria's Restaurant               Restaurant
# 11                  The Hot House Restaurant & Bar      American Restaurant
# 12                        Ka Chi Korean Restaurant        Korean Restaurant
# 13              Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 14                         Victor Restaurant & Bar                      Bar
# 15  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 16                   Green Tea Restaurant Downtown       Chinese Restaurant
# 17                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 18                      Wah Too Seafood Restaurant       Chinese Restaurant
# 19         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 20               Kensington Cornerstone Restaurant           Breakfast Spot
# 21                               Studio Restaurant           Breakfast Spot
# 22                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 23                         The Lakeview Restaurant                    Diner
# 24                     Cottage Restaurant & Lounge          Thai Restaurant
# 25             Richtree Natural Market Restaurants               Restaurant
# 26                    Yueh Tung Chinese Restaurant       Chinese Restaurant
# 27                           ONE Restaurant/Lounge  New American Restaurant
# 28                           Sightlines Restaurant      American Restaurant
# 29                   Micheal's Restaurant and Deli                      Bar
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 2                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 3                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 4                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 5                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 6                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 7                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 8                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 9                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 10              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 11                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 12                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 13               988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 14                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 15            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 16  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 17                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 18                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 19                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21                   389 Church St.  43.661500 -79.379319        M5B    ON
# 22              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 23                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 24                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 25                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 26                126 Elizabeth St.  43.655281 -79.385337        NaN    ON
# 27                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 28                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 29                   566 Queen St W  43.647289 -79.403493        NaN    ON

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name            categories  \
# 0                  Hemispheres Restaurant & Bistro   American Restaurant
# 1                           Azure Restaurant & Bar            Restaurant
# 2                                   360 Restaurant              Wine Bar
# 3                   Goldstone Noodle Restaurant 金石          Noodle House
# 4                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 5                         New Sky Restaurant 小沙田食家    Chinese Restaurant
# 6                          Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 8                     Aroma Fine Indian Restaurant     Indian Restaurant
# 10                           Victoria's Restaurant            Restaurant
# 11                  The Hot House Restaurant & Bar   American Restaurant
# 12                        Ka Chi Korean Restaurant     Korean Restaurant
# 14                         Victor Restaurant & Bar                   Bar
# 15  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 16                   Green Tea Restaurant Downtown    Chinese Restaurant
# 17                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 18                      Wah Too Seafood Restaurant    Chinese Restaurant
# 19         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 20               Kensington Cornerstone Restaurant        Breakfast Spot
# 21                               Studio Restaurant        Breakfast Spot
# 23                         The Lakeview Restaurant                 Diner
# 24                     Cottage Restaurant & Lounge       Thai Restaurant
# 25             Richtree Natural Market Restaurants            Restaurant
#
#                             address        lat        lng postalCode state
# 0               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 1                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 2                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 3                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 4                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 5                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 6                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 8                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 10              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 11                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 12                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 14                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 15            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 16  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 17                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 18                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 19                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21                   389 Church St.  43.661500 -79.379319        M5B    ON
# 23                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 24                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 25                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON

# %% [markdown]
# ## Cafeteria whereabouts

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN&client_secret=G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU&ll=43.653963,-79.387207&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1d0941735', 'name': 'D...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  53bd6dfe498e6c1d3bc9333e                                        NaN
# 3  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 4  556f826b498e07f469e6bf1f                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada                  NaN
# 3          CA       Toronto           Canada         Second Floor
# 4          CA           NaN           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                260                               [Toronto ON, Canada]
# 3                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4                431                                           [Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
# 3  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 4  [{'label': 'display', 'lat': 43.65417861938476...     43.654179
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.389443                 NaN             ON
# 3    -79.391762                 NaN             ON
# 4    -79.392555                 NaN            NaN
#
#                             name    referralId
# 0                      Cafeteria  v-1584472037
# 1              Stay Cafeteria 慢走  v-1584472037
# 2  Industrial Alliance Cafeteria  v-1584472037
# 3                 OCAD Cafeteria  v-1584472037
# 4                Dears Cafeteria  v-1584472037

# %% [markdown]
# ## Cleanup on Cafetaria Data frame

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2  Industrial Alliance Cafeteria             Cafeteria
# 3                 OCAD Cafeteria     College Cafeteria
# 4                Dears Cafeteria          Dessert Shop
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                                        NaN  CA  Toronto  Canada
# 3                             100 McCaul St.  CA  Toronto  Canada
# 4                                        NaN  CA      NaN  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2           NaN       260                               [Toronto ON, Canada]
# 3  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 4           NaN       431                                           [Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
# 3  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 4  [{'label': 'display', 'lat': 43.65417861938476...  43.654179 -79.392555
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  53bd6dfe498e6c1d3bc9333e
# 3        NaN    ON  4ec2b68a8231a83de8c45191
# 4        NaN   NaN  556f826b498e07f469e6bf1f

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2           Industrial Alliance Cafeteria             Cafeteria
# 3                          OCAD Cafeteria     College Cafeteria
# 4                         Dears Cafeteria          Dessert Shop
# 5                         Sears Cafeteria            Food Court
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7                       Med Sci Cafeteria     College Cafeteria
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                   Ryerson Hub Cafeteria     College Cafeteria
# 10                     SickKids Cafeteria            Food Court
# 11              Macdonald Block Cafeteria             Cafeteria
# 12                      Robarts Cafeteria     College Cafeteria
# 13                          OMP Cafeteria             Cafeteria
# 14                       Rogers Cafeteria            Food Court
# 15                      Choices Cafeteria            Food Court
# 16  George Brown College St. James Campus     Community College
# 17                             Marketeria            Restaurant
# 18                                The Hub     College Cafeteria
# 19    Cafeteria, Lawrence Park Collegiate           High School
# 20    Cafeteria, Lawrence Park Collegiate           Event Space
# 21                       Kasala Cafeteria    African Restaurant
# 22                           CC Cafeteria     College Cafeteria
# 23                          Innis College        Student Center
# 24               Estonian House Cafeteria                  Café
# 25                             Radio Cafe            Food Court
# 26                      Glendon Cafeteria     College Cafeteria
# 27     Lawrence Park Collegiate Cafeteria           High School
# 28  6th Floor Cafeteria 12 Concorde Place                  Café
# 29                           L5 Cafeteria      Cuban Restaurant
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                                         NaN  43.655657 -79.389443
# 3                              100 McCaul St.  43.652780 -79.391762
# 4                                         NaN  43.654179 -79.392555
# 5                                       Yonge  43.656038 -79.380672
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                                         NaN  43.660260 -79.392977
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                            350 Victoria St.  43.658475 -79.377653
# 10                      555 University Avenue  43.657584 -79.375652
# 11                                        NaN  43.663212 -79.388062
# 12                         130 St. George St.  43.664864 -79.399766
# 13                           1 Mount Pleasant  43.669801 -79.379790
# 14                                        NaN  43.669904 -79.379748
# 15                         200 Bloor Street E  43.671411 -79.381849
# 16                          200 King St. East  43.651366 -79.370158
# 17                                30 Bond St.  43.653585 -79.378843
# 18                           350 Victoria St.  43.658585 -79.380622
# 19                                        NaN  43.721732 -79.409600
# 20                                        NaN  43.723286 -79.412222
# 21                                      Bloor  43.660759 -79.424018
# 22                             951 Carlaw Ave  43.684631 -79.348862
# 23                               2 Sussex Ave  43.665556 -79.399298
# 24                       958 Broadview avenue  43.681763 -79.358246
# 25                          333 Bloor st east  43.671696 -79.380617
# 26                           2275 Bayview Ave  43.727383 -79.378080
# 27                                        NaN  43.722757 -79.413734
# 28                          12 Concorde Place  43.721861 -79.329339
# 29                                        NaN  43.723019 -79.345012
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3         NaN    ON
# 4         NaN   NaN
# 5         NaN    ON
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN   NaN
# 12        NaN    ON
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17    M5B 1W8    ON
# 18    M5B 2K3    ON
# 19        NaN   NaN
# 20        NaN   NaN
# 21        NaN   NaN
# 22        NaN    ON
# 23    M5S 1J5    ON
# 24        NaN    ON
# 25        NaN    ON
# 26        NaN    ON
# 27        NaN    ON
# 28    m3c 3k7    ON
# 29        NaN   NaN

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name         categories  \
# 1                       Stay Cafeteria 慢走   Asian Restaurant
# 8           De La Salle College Cafeteria  College Cafeteria
# 17                             Marketeria         Restaurant
# 18                                The Hub  College Cafeteria
# 23                          Innis College     Student Center
# 28  6th Floor Cafeteria 12 Concorde Place               Café
#
#                address        lat        lng postalCode state
# 1      388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 8   131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 17         30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 18    350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 23        2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 28   12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %% [markdown]
# ## Shopping Store Search

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NGC2LWZF34JVJEF042ZFUKN1TKN42ESDDJGADQMYE0QXCLVN&client_secret=G4OP1MONUTGD1UK1LRWDUKGMC2LU2F5HNRDWZRW1TMFED4WU&ll=43.653963,-79.387207&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 2  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada    btw York & Bay St                908
# 2           Canada  btwn Queen & Dundas                529
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 2                                                NaN     43.654540
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380932                            NaN             M5K 1A1
# 2    -79.380677  Downtown Toronto, Toronto, ON             M5B 2H1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1584472037
# 1             ON                TD Centre Shopping Concourse  v-1584472037
# 2             ON                     CF Toronto Eaton Centre  v-1584472037
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1584472037
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1584472037

# %% [markdown]
# ## Cleaning the Shopping Data

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 2        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       529
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [66 Wellington St W (btw York & Bay St), Toron...
# 2  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 2                                                NaN  43.654540 -79.380677
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 2  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                TD Centre Shopping Concourse     Shopping Mall
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 2        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380932    M5K 1A1    ON
# 2 -79.380677    M5B 2H1    ON

# %% [markdown]
# ## Visualizing Hotels,Shopping store and Cafetaria clusters

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df.head()
# Out:
#                             name         categories                address  \
# 0  Sheraton Centre Toronto Hotel              Hotel  123 Queen Street West
# 1                 Grand Ballroom        Event Space        123 Queen St. W
# 2              Stay Cafeteria 慢走   Asian Restaurant        388 Spadina Ave
# 3  De La Salle College Cafeteria  College Cafeteria     131 Farnham Avenue
# 4                     Marketeria         Restaurant            30 Bond St.
#
#          lat        lng postalCode state
# 0  43.650594 -79.384530    M5H 2M9    ON
# 1  43.651217 -79.383771    M5H 2M9    ON
# 2  43.655454 -79.399163    M5T 2G5    ON
# 3  43.683003 -79.397815    M4V 1H7    ON
# 4  43.653585 -79.378843    M5B 1W8    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Visualization of Park Restaurant and Cafetaria together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name            categories  \
# 0                                     Queen's Park                  Park
# 1                             Bellevue Square Park                  Park
# 2                               Canoe Landing Park                  Park
# 3                           Trinity Bellwoods Park                  Park
# 4                              Riverdale Park West                  Park
# 5                                Barbara Hall Park                  Park
# 6                                        High Park                  Park
# 7                              Riverdale Park East                  Park
# 8                  Hemispheres Restaurant & Bistro   American Restaurant
# 9                           Azure Restaurant & Bar            Restaurant
# 10                                  360 Restaurant              Wine Bar
# 11                  Goldstone Noodle Restaurant 金石          Noodle House
# 12                          Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 13                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 14                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 15                    Aroma Fine Indian Restaurant     Indian Restaurant
# 16                           Victoria's Restaurant            Restaurant
# 17                  The Hot House Restaurant & Bar   American Restaurant
# 18                        Ka Chi Korean Restaurant     Korean Restaurant
# 19                         Victor Restaurant & Bar                   Bar
# 20  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 21                   Green Tea Restaurant Downtown    Chinese Restaurant
# 22                   Hong Shing Chinese Restaurant    Chinese Restaurant
# 23                      Wah Too Seafood Restaurant    Chinese Restaurant
# 24         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 25               Kensington Cornerstone Restaurant        Breakfast Spot
# 26                               Studio Restaurant        Breakfast Spot
# 27                         The Lakeview Restaurant                 Diner
# 28                     Cottage Restaurant & Lounge       Thai Restaurant
# 29             Richtree Natural Market Restaurants            Restaurant
# 30                               Stay Cafeteria 慢走      Asian Restaurant
# 31                   De La Salle College Cafeteria     College Cafeteria
# 32                                      Marketeria            Restaurant
# 33                                         The Hub     College Cafeteria
# 34                                   Innis College        Student Center
# 35           6th Floor Cafeteria 12 Concorde Place                  Café
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 2                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 3                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 4                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 5                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 6                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 7                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 8               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 9                    225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 10                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 11                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 12                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 13                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 14                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 15                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 16              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 17                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 18                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 19                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 21  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 22                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 23                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 24                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 25               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 28                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 29                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 30                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 31               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 32                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 33                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 34                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 35                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Final Observation

# %% [markdown]
# 1. There is a definite opportunity for the delegates to be housed in and around Queens
# 2. Sheraton Hotel seems like a good choice considering there is a event place available to host the meeting
# 3. The second map provides for the families of the visiting delegates who would be interested on recreational pursuits
# 4. The area in and around Queens have ample parks,restaurant and cafetaria
# 5. Therefore the delegates need to be housed in the Queens locality and preferably at Sheraton
#
# Disclaimer:
#
# The Above observation/conclusion is bereft of other factors like cost and ratings and could be a future study artifact

# %% [markdown]
# Link to Watson Notebook: https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/f583b945-c9d6-4462-bd20-551fa2d3bb73/view?access_token=c97f51423c54b698c5837dadeb2feab1d3d44c4cc9e82f768f0e3999f24c5de2
